# %%
import torch
import json 
from transformers import T5Tokenizer, T5ForConditionalGeneration, T5Config

model = T5ForConditionalGeneration.from_pretrained('t5-small')
tokenizer = T5Tokenizer.from_pretrained('t5-small')
device = torch.device('cpu')
def summarise(text):
    preprocess_text = text.strip().replace("\n","")
    t5_prepared_Text = "summarize: "+preprocess_text

    tokenized_text = tokenizer.encode(t5_prepared_Text, return_tensors="pt").to(device)


# summmarize 
    summary_ids = model.generate(tokenized_text,
                                    num_beams=4,
                                    no_repeat_ngram_size=2,
                                    min_length=30,
                                    max_length=100,
                                    early_stopping=True)

    output = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

#     print ("\n\nSummarized text: \n",output)
    return output

# %%
import numpy as np
import pandas as pd 
data=pd.read_csv("../Clean Data/clean_consolidated_furniture (forum).csv",nrows=100000)
data["Summary"] = data["Body"]

data["Summary"] = data['Body'].apply(summarise)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (2603 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (1451 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (518 > 512). Running this sequence through the model will result in indexing errors

# %%
data
# Out:
#      Unnamed: 0                  Author  \
# 0             0             chris888222
# 1             1  Littledragonpapertiger
# 2             2               focus1974
# 3             3                      tk
# 4             4                  snowyg
# ..          ...                     ...
# 141         141                chixchix
# 142         142               mrsmonkie
# 143         143     sundaymorningstaple
# 144         144               mrsmonkie
# 145         145                  beatle
#
#                                                   Body     Reply to  \
# 0    I am looking for a teak wood wardrobe... so fa...          NaN
# 1    Can try Widharja. Did you check out Tan Boon L...  chris888222
# 2    if you are adventurours... quite a few singapo...          NaN
# 3    TS asking about office chair and u recommend s...    focus1974
# 4    for solid teak furniture go to www.hewn.sg v s...          NaN
# ..                                                 ...          ...
# 141  Hii anyone ever bought teak furniture from thi...            -
# 142  Sorry can't help with the room by room place.\...     chixchix
# 143  You can also ScanTeak:\r\n\r\nHawaii Furnishin...     chixchix
# 144  Ignore the Gillman Village place I previously ...     chixchix
# 145  Another note about Mirage Fine Teak in case an...    mrsmonkie
#
#                                    Message Replying to  \
# 0    I am looking for a teak wood wardrobe... so fa...
# 1    Can try Widharja. Did you check out Tan Boon L...
# 2    if you are adventurours... quite a few singapo...
# 3    TS asking about office chair and u recommend s...
# 4    for solid teak furniture go to www.hewn.sg v s...
# ..                                                 ...
# 141                                                  -
# 142  Hii anyone ever bought teak furniture from thi...
# 143  Hii anyone ever bought teak furniture from thi...
# 144  Hii anyone ever bought teak furniture from thi...
# 145  Ignore the Gillman Village place I previously ...
#
#                                              Permalink  Score  \
# 0                                                  NaN    NaN
# 1                                                  NaN    NaN
# 2                                                  NaN    NaN
# 3                                                  NaN    NaN
# 4                                                  NaN    NaN
# ..                                                 ...    ...
# 141  https://forum.singaporeexpats.com/viewtopic.ph...    0.0
# 142  https://forum.singaporeexpats.com/viewtopic.ph...    0.0
# 143  https://forum.singaporeexpats.com/viewtopic.ph...    0.0
# 144  https://forum.singaporeexpats.com/viewtopic.ph...    0.0
# 145  https://forum.singaporeexpats.com/viewtopic.ph...    0.0
#
#                 TimeStamp  Year           Source  \
# 0    17-10-2016, 08:35 PM  2016     HardWareZone
# 1    18-10-2016, 09:01 PM  2016     HardWareZone
# 2    03-01-2015, 06:54 PM  2015     HardWareZone
# 3    15-01-2015, 09:17 AM  2015     HardWareZone
# 4    23-05-2016, 05:02 PM  2016     HardWareZone
# ..                    ...   ...              ...
# 141    06/07/2008 11:35am  2021  Singapore Expat
# 142    17/07/2008 09:05am  2021  Singapore Expat
# 143    17/07/2008 12:33pm  2021  Singapore Expat
# 144    17/07/2008 02:18pm  2021  Singapore Expat
# 145    05/10/2008 04:50pm  2021  Singapore Expat
#
#                                                Summary
# 0    I am looking for a teak wood wardrobe... so fa...
# 1    can try Widharja. Did you check out Tan Boon L...
# 2    singaporeans go to JB to buy furniture. they d...
# 3    TS asking about office chair and u recommend s...
# 4    for solid teak furniture go to www.hewn.sg vs....
# ..                                                 ...
# 141  hii anyone ever bought teak furniture from thi...
# 142  we're buying a bed there as well, which again ...
# 143  you can also ScanTeak: Hawaii Furnishing Pte L...
# 144  Ignore the Gillman Village place I previously ...
# 145  an outdoor furniture set from Mirage Fine Teak...
#
# [146 rows x 11 columns]

# %%
data.to_csv('furniture_summary.csv', index=False)
